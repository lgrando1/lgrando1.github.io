# %% [markdown]
# ---
#
# title: Running Python code inside Netlogo
# author: ''
# date: '2023-08-26'
# slug: NetlogoPython
# categories: []
# tags: [ "Agent-Based", "Python", "Netlogo"]
# subtitle: ''
# Summary: ''
# authors: []
# lastmod: '2023-08-19T16:00:00-03:00'
# featured: yes
# image:
#   caption: ''
#   focal_point: ''
#   preview_only: no
# projects: []
#
# ---
